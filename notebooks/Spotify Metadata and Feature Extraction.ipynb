# %% [markdown]
# # Spotify Metadata and Audio Feature Extraction
#
# This notebook processes a collection of MP3 files to extract metadata, search for corresponding tracks on Spotify, and retrieve audio features using the Spotify Web API. It demonstrates the integration of local file analysis with cloud-based music data services to enrich a music dataset.

# %% [markdown]
# ## Import Libraries

# %%
import os
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import json
from mutagen.mp3 import MP3
from mutagen.easyid3 import EasyID3
from tqdm import tqdm
from glob import glob

# %% [markdown]
# ## Initialize Spotify Client
#
# The Spotify client is initialized with credentials stored in a JSON file. These credentials include the `client_id` and `client_secret` necessary for accessing the Spotify Web API. The `SpotifyClientCredentials` manager handles the OAuth 2.0 flow for server-to-server authentication.
#
# Using any text editor, create a new text file containing the following information. Save the text file as "spotify_credentials.json" and place in '../data/reference' folder.
#
# ```
# {
#   "client_id":"REPLACE WITH CLIENT ID",
#   "client_secret":"REPLACE WITH SECRET",
#   "user_id":"REPLACE WITH SPOTIFY USERNAME"
# }
# ```
# Retrieve your client ID and secret here: https://developer.spotify.com/dashboard/
#
# And your username here: https://www.spotify.com/us/account/overview/
#
# Add "http://localhost:8080/callback" to Spotify redirect_uri

# %%
# Load the credentials
credentials_path = r'../data/reference/spotify_credentials.json' # Path to your spotify_credentials.json file

with open(credentials_path, 'r') as file:
    creds = json.load(file)

# Initialize the Spotify client credentials manager with your client_id and client_secret
auth_manager = SpotifyClientCredentials(client_id=creds['client_id'], client_secret=creds['client_secret'])

# Initialize the Spotipy client with the credentials manager
sp = spotipy.Spotify(auth_manager=auth_manager)

# %% [markdown]
# ### Functions

# %%
def parse_mp3_metadata(file_path):
    """
    Reads MP3 metadata from a given file path.

    This function extracts the track's title and artist(s) from an MP3 file's metadata.
    It handles multiple artists separated by commas or slashes and cleans up the title
    by removing any '(feat.)' annotations.

    Parameters:
    - file_path (str): The file path of the MP3 file to read metadata from.

    Returns:
    - tuple: A tuple containing the track's title and a list of artist names.
             If an error occurs, it returns None for the track title and an empty list for artists.
    """
    try:
        audiofile = MP3(file_path, ID3=EasyID3)
        track_title = audiofile.get('title', [None])[0]
        artist_string = audiofile.get('artist', [None])[0]
        
        # Split artists by comma and then by slash
        artists = []
        if artist_string:
            artist_parts = artist_string.split(',')
            for part in artist_parts:
                artists.extend(part.split('/'))
        
        # Remove any leading and trailing spaces from artist names
        artists = [artist.strip() for artist in artists]
        
        # Clean up the track title
        track_title = track_title.split(' (feat.')[0].strip() if track_title else None
        
        return track_title, artists
    except Exception as e:
        print(f"Error reading metadata for {file_path}: {e}")
        return None, []


def get_ids_and_genre(track_title, artists, sp):
    """
    Searches for a track's ID and associated genres on Spotify using a track's title and artists.

    The function performs a search on Spotify for each artist combined with the track's title.
    It returns the first match's track ID, artist IDs, and a list of unique genres associated
    with all artists. The search stops once a match is found.

    Parameters:
    - track_title (str): The title of the track to search for.
    - artists (list): A list of artist names associated with the track.
    - sp (Spotify client): An authenticated instance of the Spotify client to perform API calls.

    Returns:
    - tuple: A tuple containing a list of artist IDs, a list of unique genres, and the track's ID.
             If no match is found, it returns None for artist IDs and track ID, and an empty list for genres.
    """
    unique_genres = set()  # Use a set to automatically discard duplicates
    track_id, artist_ids = None, None

    for artist in artists:
        # Format the search query
        query = f"track:{track_title} artist:{artist.strip()}"

        # Search for tracks
        track_results = sp.search(q=query, type='track', limit=1)
        if track_results['tracks']['items']:
            track_item = track_results['tracks']['items'][0]
            track_id = track_item['id']
            artist_ids = [artist['id'] for artist in track_item['artists']]

            # Get genres from the track's artists
            for artist_id in artist_ids:
                artist_genre = sp.artist(artist_id)['genres']
                unique_genres.update(artist_genre)

            # Since we found the track, we don't need to continue searching
            break

    # Return the results
    if track_id and artist_ids:
        return artist_ids, list(unique_genres), track_id
    else:
        return None, None, []  # Return None and an empty list if no match was found


def get_spotify_audio_features(artist_ids, genre_list, track_id, sp):
    """
    Retrieves audio features for a given track ID from Spotify and returns them in a DataFrame.

    This function calls the Spotify API to get audio features for a specific track ID.
    It then creates a pandas DataFrame with these audio features, along with additional
    columns for the track ID, artist IDs, and genres. Certain unnecessary columns are dropped
    from the DataFrame before it is returned.

    Parameters:
    - artist_ids (list): A list of Spotify artist IDs.
    - genre_list (list): A list of genres associated with the track.
    - track_id (str): The Spotify track ID for which to retrieve audio features.
    - sp (Spotify client): An authenticated instance of the Spotify client to perform API calls.

    Returns:
    - DataFrame: A pandas DataFrame containing the audio features, track ID, artist IDs, and genres.
                 If no audio features are found, an empty DataFrame with the specified columns is returned.
    """
    
    # Retrieve audio features for the given track_id using the Spotify API
    audio_features = sp.audio_features(track_id)[0]
    
    # If the audio_features is not None, create a DataFrame
    if audio_features:
        # Create a DataFrame from the audio features dictionary
        df = pd.DataFrame([audio_features])
        
        # Add track_id, artist_ids, and genre_list as additional columns
        df['track_id'] = track_id
        df['artist_ids'] = [artist_ids]  # Enclose in a list to ensure it's treated as a single column value
        df['genre_list'] = [genre_list]  # Enclose in a list to ensure it's treated as a single column value
        
        # Drop specified columns from the DataFrame
        columns_to_drop = ['type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms']
        df.drop(columns=columns_to_drop, inplace=True)
        
    else:
        # If audio_features is None, create an empty DataFrame with the columns set to None
        df = pd.DataFrame({
            'track_id': [track_id],
            'artist_ids': [artist_ids],
            'genre_list': [genre_list],
            # Additional keys can be set to None if needed, depending on the expected audio feature keys
        })
        # Ensure the columns to be dropped are also reflected in the empty DataFrame
        for column in ['type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms']:
            df[column] = None
        df.drop(columns=columns_to_drop, inplace=True)

    return df


def main(sp, directory):
    """
    Processes MP3 files in a given directory, extracting metadata, searching for Spotify track and artist IDs and genres,
    and retrieving audio features to generate a comprehensive DataFrame.

    Parameters:
    - sp (SpotifyClientCredentials): An authenticated instance of the Spotify client to perform API calls.
    - directory (str): The directory path containing MP3 files to be processed.

    Returns:
    - DataFrame: A pandas DataFrame containing Spotify audio features and metadata for all processed MP3 files.
    """

    # Initialize an empty DataFrame to store all tracks' info
    all_tracks_df = pd.DataFrame()
    
    # Get a list of all MP3 files in the directory
    mp3_files = glob(os.path.join(directory, '*.mp3'))

    # Start processing each MP3 file
    for index, file_path in enumerate(mp3_files, start=1):
        print(f"Processing file {index} of {len(mp3_files)}: {os.path.basename(file_path)}")

        # Parse MP3 metadata (Assuming 'parse_mp3_metadata' is a defined function)
        track_title, artists = parse_mp3_metadata(file_path)

        # Continue only if metadata was successfully parsed
        if track_title and artists:
            # Search for Spotify track and artist IDs, and genres
            artist_ids, genres, track_id = get_ids_and_genre(track_title, artists, sp)

            # Continue only if a Spotify match was found
            if track_id and artist_ids:
                # Retrieve Spotify audio features (Assuming 'get_spotify_audio_features' is a defined function)
                audio_features_df = get_spotify_audio_features(artist_ids, genres, track_id, sp)

                # Continue only if audio features were successfully retrieved
                if not audio_features_df.empty:
                    # Add track_name, artist_names, and filename columns
                    audio_features_df['track_name'] = track_title
                    audio_features_df['artist_names'] = ', '.join(artists)
                    audio_features_df['filename'] = os.path.basename(file_path)

                    # Append this track's DataFrame to the main DataFrame
                    all_tracks_df = pd.concat([all_tracks_df, audio_features_df], ignore_index=True)

    return all_tracks_df

# %%
directory = r'../data/audio_files/raw_download'
tracks_df = main(sp, directory)
# Out:
# Processing file 1 of 364: 88rising, BIBI - The Weekend.mp3
# Processing file 2 of 364: AC Slater - Bass Inside.mp3
# Processing file 3 of 364: AC Slater, Chris Lorenzo - Fly Kicks - Wax Motif Remix.mp3
# Processing file 4 of 364: AIKA, TOFIE - Space Girl.mp3
# Processing file 5 of 364: Alesso, Nico & Vinz - I Wanna Know - Alesso & Deniz Koyu Remix.mp3
# Processing file 6 of 364: Alina Baraz - Between Us.mp3
# Processing file 7 of 364: Allie X, Mitski - Susie Save Your Love.mp3
# Processing file 8 of 364: Anamanaguchi, HANA - On My Own.mp3
# Processing file 9 of 364: Andrea Chahayed - Belong.mp3
# Processing file 10 of 364: Ark Patrol, Veronika Redd - Let Go - Phantoms Remix.mp3
# Processing file 11 of 364: Audien - Escape (with Nomra).mp3
# Processing file 12 of 364: Audien - See You On The Other Side [Upmost Remix].mp3
# Processing file 13 of 364: Audien - See You On The Other Side.mp3
# Processing file 14 of 364: Audien, Cate Downey - Wish It Was You.mp3
# Processing file 15 of 364: Audien, Lady A - Something Better.mp3
# Processing file 16 of 364: Audien, XIRA - One Last Dance.mp3
# Processing file 17 of 364: AUDREY NUNA - Baby Blues.mp3
# Processing file 18 of 364: AUDREY NUNA - damn Right.mp3
# Processing file 19 of 364: Autoerotique - Bling (feat. Lady Leshurr).mp3
# Processing file 20 of 364: BAYNK - When I'm Alone.mp3
# Processing file 21 of 364: Bellecour - Everybody Goes.mp3
# Processing file 22 of 364: Big Wild - Joypunks.mp3
# Processing file 23 of 364: BLACKPINK - Pink Venom.mp3
# Processing file 24 of 364: Bleu Clair - Funk Accelerator.mp3
# Processing file 25 of 364: Bleu Clair - Have Me All (feat. Jelita).mp3
# Processing file 26 of 364: Bleu Clair - Hypnotized.mp3
# Processing file 27 of 364: Bleu Clair - Sand Dunes.mp3
# Processing file 28 of 364: Bleu Clair - Step Into It.mp3
# Processing file 29 of 364: Bleu Clair, Dances With White Girls - Peanut Butter.mp3
# Processing file 30 of 364: Bleu Clair, OOTORO, Chyra - Killer Bee.mp3
# Processing file 31 of 364: Blonde - All Cried Out (feat. Alex Newell) - Radio Edit.mp3
# Processing file 32 of 364: Bodysync, Ryan Hemsworth, Giraffage - Fantasy.mp3
# Processing file 33 of 364: Born Dirty, Bellecour - Tokyo Bill.mp3
# Processing file 34 of 364: Brittany Howard, Fred again.., Joy Anonymous - Stay High again...mp3
# Processing file 35 of 364: Calica, Magdalena Bay - Superficial Love.mp3
# Processing file 36 of 364: CAPYAC - Ooeeooeeoo - Teddy Roxpin & Lando Chill Remix.mp3
# Processing file 37 of 364: Cazztek - Don't Let The Bass Get Ya.mp3
# Processing file 38 of 364: Cazztek - To The Beat.mp3
# Processing file 39 of 364: Chris Lake - I Want You.mp3
# Processing file 40 of 364: Chris Lake - In The Yuma (feat. Aatig).mp3
# Processing file 41 of 364: Chris Lake - Operator (Ring Ring) [feat. Dances With White Girls].mp3
# Processing file 42 of 364: Chris Lake - Stay With Me.mp3
# Processing file 43 of 364: Chris Lake - Turn off the Lights (feat. Alexis Roberts).mp3
# Processing file 44 of 364: Chris Lake, Destructo - Y.O.D.O.mp3
# Processing file 45 of 364: Chris Lake, Walker & Royce - Drop Top.mp3
# Processing file 46 of 364: Chromeo - Words With You - Tchami Remix.mp3
# Processing file 47 of 364: CloZee - Microworlds.mp3
# Processing file 48 of 364: CloZee, Britt Lari, Dreamers Delight - Back To The Top.mp3
# Processing file 49 of 364: CloZee, Ella Vos - Glow In The Dark.mp3
# Processing file 50 of 364: Codes - So Damn Funky.mp3
# Processing file 51 of 364: counsel pop - jd sports.mp3
# Processing file 52 of 364: Curbi - Seeing Is Believing.mp3
# Processing file 53 of 364: DACEY - BITTER.mp3
# Processing file 54 of 364: Damien N-Drix - Wingz.mp3
# Processing file 55 of 364: Damien N-Drix, jeonghyeon - Not Available.mp3
# Processing file 56 of 364: Dance Fruits Music, DMNDS - Calabria (feat. Fallen Roses, Lujavo & Lunis) - Shift K3Y Edit.mp3
# Processing file 57 of 364: Daniel Allan, han.irl 3, Rome in Silver - Elysian Park.mp3
# Processing file 58 of 364: Darius, Amaria - FADED.mp3
# Processing file 59 of 364: Darius, Darianna Everett - CHERIE.mp3
# Processing file 60 of 364: Darius, Devin Tracy - EASE YOUR MIND.mp3
# Processing file 61 of 364: Darius, Duñe - FEELS RIGHT.mp3
# Processing file 62 of 364: Darius, Lo Village - MATERIAL GIRL.mp3
# Processing file 63 of 364: deadmau5 - imaginary friends (ov) - Morgan Page Remix.mp3
# Processing file 64 of 364: Denis First - Heart Isn't Home - Volac Remix.mp3
# Processing file 65 of 364: Destructo - Bandz (feat. Yo Gotti, Kevin Gates & Denzel Curry) - Loge21 Remix.mp3
# Processing file 66 of 364: Dillon Francis - DFR - Black Caviar Remix.mp3
# Processing file 67 of 364: Dillon Francis - Still Not Butter.mp3
# Processing file 68 of 364: Dillon Francis, Aleyna Tilki - Real Love - Shelco Garcia & Teenwolf Remix.mp3
# Processing file 69 of 364: Dillon Francis, G-Eazy - Say Less - Dillon Francis & Moksi Remix.mp3
# Processing file 70 of 364: Dillon Marinez - Wormhole.mp3
# Processing file 71 of 364: Dillon Nathaniel - Feel Alright.mp3
# Processing file 72 of 364: Dillon Nathaniel - Obsessions.mp3
# Processing file 73 of 364: Disclosure, Lorde - Magnets - A-Trak Remix.mp3
# Processing file 74 of 364: DJ CHARI, DJ TATSUKI, ZOT on the WAVE, Tyson, SANTAWORLDVIEW, MonyHorse - JET MODE.mp3
# Processing file 75 of 364: DJ Hanzel, Dillon Francis - Gumby.mp3
# Processing file 76 of 364: Doja Cat - Get Into It (Yuh).mp3
# Processing file 77 of 364: Doja Cat - Kiss Me More (feat. SZA).mp3
# Processing file 78 of 364: Doja Cat - Woman.mp3
# Processing file 79 of 364: Dom Dolla - Strangers (with Mansionair).mp3
# Processing file 80 of 364: Dom Dolla - Take It.mp3
# Processing file 81 of 364: Dombresky - Soul Sacrifice.mp3
# Processing file 82 of 364: Dreamer Isioma - Stop Calling The Police On Me.mp3
# Processing file 83 of 364: Dreamer Isioma - Valentina.mp3
# Processing file 84 of 364: Duskus - Wild.mp3
# Processing file 85 of 364: Eden Prince, Nonô - Memories.mp3
# Processing file 86 of 364: Ekali, NITTI - Power.mp3
# Processing file 87 of 364: Elephant Heart - Summer Of Saigon.mp3
# Processing file 88 of 364: ELIO - @elio.irl.mp3
# Processing file 89 of 364: Elohim - Good Day Bad Day - Snakehips Remix.mp3
# Processing file 90 of 364: Eprom, G Jones - Daemon Veil.mp3
# Processing file 91 of 364: Exmag - Going Down Slow.mp3
# Processing file 92 of 364: FAKY - Departure.mp3
# Processing file 93 of 364: FAKY - little more.mp3
# Processing file 94 of 364: Feed Me - Frank Frazetta.mp3
# Processing file 95 of 364: FIFTY FIFTY - Cupid - Twin Ver..mp3
# Processing file 96 of 364: FISHER - Losing It - Radio Edit.mp3
# Processing file 97 of 364: FISHER - Stop It.mp3
# Processing file 98 of 364: Flume - Rhinestone 1.7.2 [2018 Export Wav] feat. Isabella Manfredi.mp3
# Processing file 99 of 364: Format-B - Chunky.mp3
# Processing file 100 of 364: Franc Moody - I'm in a Funk.mp3
# Processing file 101 of 364: Fred again.. - Kyle (i found you).mp3
# Processing file 102 of 364: FUKUSHIGE MARI - 生きていくだけで (feat. Ruri).mp3
# Processing file 103 of 364: G Jones - Understanding the Possibility.mp3
# Processing file 104 of 364: G Jones - Which Way.mp3
# Processing file 105 of 364: Galantis, Throttle - Tell Me You Love Me.mp3
# Processing file 106 of 364: Giraffage, Japanese Breakfast - Maybes.mp3
# Processing file 107 of 364: Good Times Ahead - True Romance (feat. Jarina De Marco) - Chris Lake Remix.mp3
# Processing file 108 of 364: Grant, McCall - Wishes.mp3
# Processing file 109 of 364: GRiZ - Laser Fire.mp3
# Processing file 110 of 364: GRiZ - Let's Get Weird.mp3
# Processing file 111 of 364: GRiZ - Your Light.mp3
# Processing file 112 of 364: Habstrakt - Infinite.mp3
# Processing file 113 of 364: Habstrakt, Jace Mek - I Wanna.mp3
# Processing file 114 of 364: Habstrakt, josh pan - Movie - SQWAD Remix.mp3
# Processing file 115 of 364: HANRORO - MIRROR.mp3
# Processing file 116 of 364: Haywyre - Tell Me - Ellis Remix.mp3
# Processing file 117 of 364: Herobust - Move Mint - VIP.mp3
# Processing file 118 of 364: Herobust - WTF VIP - Herobust VIP Mix.mp3
# Processing file 119 of 364: Hikaru Utada - Give Me A Reason.mp3
# Processing file 120 of 364: Hikaru Utada - time will tell.mp3
# Processing file 121 of 364: HypeerTime - Can't Sleep.mp3
# Processing file 122 of 364: INZO - Angst.mp3
# Processing file 123 of 364: INZO - Bass In Yo Face.mp3
# Processing file 124 of 364: INZO, Blookah, Leo Napier - Let It Slide.mp3
# Processing file 125 of 364: Isaiah Rashad - Wat U Sed (feat. Doechii & Kal Banx).mp3
# Processing file 126 of 364: Jenevieve - Rendezvous.mp3
# Processing file 127 of 364: JNTHN STEIN - Jam.mp3
# Processing file 128 of 364: Jo Hill - HONEYMOON.mp3
# Processing file 129 of 364: jomm, readyaimfire27 - Come and Go.mp3
# Processing file 130 of 364: Jonas Aden, RebMoe - I Don't Speak French (Adieu).mp3
# Processing file 131 of 364: Josie Man - jealous in my dreams.mp3
# Processing file 132 of 364: JOYRYDE - 4AM.mp3
# Processing file 133 of 364: Kaivon - I Feel It.mp3
# Processing file 134 of 364: Kaskade - Hot Wheels.mp3
# Processing file 135 of 364: Kaskade, Too Many Zooz - Jorts FTW.mp3
# Processing file 136 of 364: KATIE - Faux.mp3
# Processing file 137 of 364: kd, KOTONOHOUSE, RANASOL - IN YOUR EYES 「瞳の中で」.mp3
# Processing file 138 of 364: keshi - us.mp3
# Processing file 139 of 364: Khakii, Colde - BASS.mp3
# Processing file 140 of 364: Kill Paris - Red Lights (feat. Dotter) [Just A Gent Remix].mp3
# Processing file 141 of 364: Klypso, Snoop Dogg, Doggface, War - Low Rider (2livemafia Remix).mp3
# Processing file 142 of 364: Knock2 - REWiND - Wolfgang Gartner Remix.mp3
# Processing file 143 of 364: Kyoto Black, TetraTara - Looking Pretty.mp3
# Processing file 144 of 364: L8ching - Real World.mp3
# Processing file 145 of 364: Laika Beats - Space Dog.mp3
# Processing file 146 of 364: Lane 8, Channy Leaneagh - I'll Wait - Le Youth Remix.mp3
# Processing file 147 of 364: Le Youth - Chills.mp3
# Processing file 148 of 364: LeeHi - Bye.mp3
# Processing file 149 of 364: Lemaitre - Reflection.mp3
# Processing file 150 of 364: Lemaitre, RebMoe - Ok Computer.mp3
# Processing file 151 of 364: Lemaitre, Sofiloud - Trip Sitter.mp3
# Processing file 152 of 364: Lexie Liu - i wanna tell u.mp3
# Processing file 153 of 364: Lexie Liu - SHADOW.mp3
# Processing file 154 of 364: Lexie Liu - 了 L.mp3
# Processing file 155 of 364: Lexie Liu - 香芋的错觉 CAROUSEL.mp3
# Processing file 156 of 364: Lindsey Stirling, RuthAnne - Love's Just a Feeling (feat. Rooty).mp3
# Processing file 157 of 364: LION BABE - Wonder Woman - NVOY Remix.mp3
# Processing file 158 of 364: Loge21 - Break It Down - Original Mix.mp3
# Processing file 159 of 364: Loge21 - Drop That.mp3
# Processing file 160 of 364: Loge21 - Ghetto Symphony.mp3
# Processing file 161 of 364: Loge21 - New Life.mp3
# Processing file 162 of 364: LoJ - It Made Me Fearless - ASHEZ Remix.mp3
# Processing file 163 of 364: LSDREAM, INZO - BLASTA.mp3
# Processing file 164 of 364: LSDREAM, Shlump - R.A.V.E - Zingara Remix.mp3
# Processing file 165 of 364: LSDREAM, Shlump, Sarah Hudson - STARCHILD.mp3
# Processing file 166 of 364: Luca Lush - Vermilion.mp3
# Processing file 167 of 364: Madeon - Beings.mp3
# Processing file 168 of 364: Madeon - Love You Back.mp3
# Processing file 169 of 364: Madi Sipes & The Painted Blue - 8-00.mp3
# Processing file 170 of 364: Maeta - Teen Scene (ft. Buddy) - Wax Motif Remix.mp3
# Processing file 171 of 364: Magdalena Bay - Killshot.mp3
# Processing file 172 of 364: Magdalena Bay - U Wanna Dance.mp3
# Processing file 173 of 364: Malaa - Bling Bling (2020 Remix).mp3
# Processing file 174 of 364: Malaa - Bling Bling (Delayers Remix).mp3
# Processing file 175 of 364: Malaa - Bling Bling.mp3
# Processing file 176 of 364: Malaa - Bylina (Bellecour Remix).mp3
# Processing file 177 of 364: Malaa, Dombresky - Hostyl.mp3
# Processing file 178 of 364: MARINA - Primadonna.mp3
# Processing file 179 of 364: Marten Hørger - Anøther Dimensiøn.mp3
# Processing file 180 of 364: Marten Hørger - GONNA BE ME.mp3
# Processing file 181 of 364: Marten Hørger - I Am Ready.mp3
# Processing file 182 of 364: Marten Hørger - Jungle.mp3
# Processing file 183 of 364: Marten Hørger, Neon Steve - Heavy.mp3
# Processing file 184 of 364: Marten Hørger, Neon Steve - You Don't.mp3
# Processing file 185 of 364: Mat Zo - Deep Inside - Extended.mp3
# Processing file 186 of 364: Mat Zo - Motivate.mp3
# Processing file 187 of 364: Matroda - Bang (feat. Dances With White Girls) - ANGELZ Remix.mp3
# Processing file 188 of 364: Matroda - Bang (feat. Dances With White Girls).mp3
# Processing file 189 of 364: Matroda - Boom Bap.mp3
# Processing file 190 of 364: Matroda - D.A.N.C.I.N.G.mp3
# Processing file 191 of 364: Matroda - Deep Inside 2020.mp3
# Processing file 192 of 364: Matroda - Do You Remember House.mp3
# Processing file 193 of 364: Matroda - Main Ingredients.mp3
# Processing file 194 of 364: Matroda - Mozart.mp3
# Processing file 195 of 364: Matroda - My Mind.mp3
# Processing file 196 of 364: Matroda - True G (feat. BRUX).mp3
# Processing file 197 of 364: Matroda - Walk In The Spot.mp3
# Processing file 198 of 364: Matroda - Wasting Time.mp3
# Processing file 199 of 364: Matroda, Bleu Clair - Disco Tool - Taiki Nulight Remix.mp3
# Processing file 200 of 364: Matroda, Bleu Clair - Disco Tool.mp3
# Processing file 201 of 364: Matroda, Bleu Clair - PWR.mp3
# Processing file 202 of 364: Matroda, Loge21 - Raise Em Up.mp3
# Processing file 203 of 364: Matroda, San Pacho - The One.mp3
# Processing file 204 of 364: Matroda, Tom Budin - Body Move.mp3
# Processing file 205 of 364: MAX - IT'S YOU (feat. keshi).mp3
# Processing file 206 of 364: MAX - STRINGS (feat. JVKE & Bazzi) - Party Pupils Remix.mp3
# Processing file 207 of 364: Max Styler - Sweet (feat. Alex Hosking).mp3
# Processing file 208 of 364: maye - Yours.mp3
# Processing file 209 of 364: MEDUZA, GENESI - Everything You Have Done.mp3
# Processing file 210 of 364: Mia Rodriguez - Shut Up.mp3
# Processing file 211 of 364: MICHELLE - UNBOUND.mp3
# Processing file 212 of 364: Midnight Kids - Bad For You (feat. 90's Kids) - Party Pupils Remix.mp3
# Processing file 213 of 364: Mura Masa, Daniela Lalita - Love.mp3
# Processing file 214 of 364: Nana Lourdes - Made Your Mama Cry.mp3
# Processing file 215 of 364: NewJeans - ETA.mp3
# Processing file 216 of 364: NewJeans - Hurt.mp3
# Processing file 217 of 364: NewJeans - OMG.mp3
# Processing file 218 of 364: Nick Smith - Hold Up.mp3
# Processing file 219 of 364: Niko The Kid - Atmosphere.mp3
# Processing file 220 of 364: NITTI - Fear.mp3
# Processing file 221 of 364: NITTI, Hadar Adora - Sex Drive.mp3
# Processing file 222 of 364: Noizu - Dance.mp3
# Processing file 223 of 364: Noizu - For Your Soul.mp3
# Processing file 224 of 364: Noizu - Jungle.mp3
# Processing file 225 of 364: Noizu - Lasers.mp3
# Processing file 226 of 364: Noizu - No More.mp3
# Processing file 227 of 364: Noizu, Tony Romera - 4 The People.mp3
# Processing file 228 of 364: ODESZA, Sasha Alex Sloan - Falls - Golden Features Remix.mp3
# Processing file 229 of 364: Oski, Allen Mock, Herbalistek - Okami.mp3
# Processing file 230 of 364: OVSKY - Start Again.mp3
# Processing file 231 of 364: Party Favor, Baauer - MDR.mp3
# Processing file 232 of 364: Party Pupils - Break It Down.mp3
# Processing file 233 of 364: Pedestrian Tactics - matingcall.exe.mp3
# Processing file 234 of 364: Pedestrian Tactics - Nerds Trying To Dance.mp3
# Processing file 235 of 364: PEZNT, Born I - Breakfast.mp3
# Processing file 236 of 364: Phantoms - Designs for You.mp3
# Processing file 237 of 364: Phantoms - Do It Again.mp3
# Processing file 238 of 364: Phantoms, Anna Clendening - Say It.mp3
# Processing file 239 of 364: Phantoms, Jem Cooke - Lay It All On Me.mp3
# Processing file 240 of 364: Phantoms, Sarah Close - Moonlight.mp3
# Processing file 241 of 364: Phlegmatic Dogs - Keepmastik.mp3
# Processing file 242 of 364: PinkPantheress - Boy's a Liar.mp3
# Processing file 243 of 364: Player Dave, REXEX - Polkadot.mp3
# Processing file 244 of 364: Porter Robinson - Get Your Wish - DJ NOT PORTER ROBINSON Remix.mp3
# Processing file 245 of 364: Porter Robinson - Lifelike.mp3
# Processing file 246 of 364: Porter Robinson, League of Legends - Everything Goes On.mp3
# Processing file 247 of 364: Porter Robinson, Totally Enormous Extinct Dinosaurs - Unfold.mp3
# Processing file 248 of 364: Proxy, AC Slater - Magic Word.mp3
# Processing file 249 of 364: Redfield - Don't Worry - Axwell Cut.mp3
# Processing file 250 of 364: Ren Carter, Liv Grace - Frog.mp3
# Processing file 251 of 364: Rezz, kd - Fourth Impact.mp3
# Processing file 252 of 364: Rezz, Kotek - Teleportal.mp3
# Processing file 253 of 364: Rezz, Malaa - Criminals.mp3
# Processing file 254 of 364: Rome in Silver - Beam.mp3
# Processing file 255 of 364: Rome in Silver - Cicero.mp3
# Processing file 256 of 364: Rome in Silver - Fill Up My Soul.mp3
# Processing file 257 of 364: Rome in Silver - Fool.mp3
# Processing file 258 of 364: Rome in Silver - Inferno.mp3
# Processing file 259 of 364: Rome in Silver - Tempest.mp3
# Processing file 260 of 364: Rome in Silver - Think About It.mp3
# Processing file 261 of 364: Rome in Silver - Touch.mp3
# Processing file 262 of 364: Rome in Silver - Waiting....mp3
# Processing file 263 of 364: Rome in Silver - Yoko.mp3
# Processing file 264 of 364: Rome in Silver - You Don't Know (what it's like).mp3
# Processing file 265 of 364: Rome in Silver, chae - Friends.mp3
# Processing file 266 of 364: ROSÉ - On The Ground.mp3
# Processing file 267 of 364: SACHI, Naïka - Enchanté - Phantoms Remix.mp3
# Processing file 268 of 364: Saint Punk - Howl.mp3
# Processing file 269 of 364: Saint Punk - MAD.mp3
# Processing file 270 of 364: Saint Punk - Menace.mp3
# Processing file 271 of 364: Saint Punk, J - 911.mp3
# Processing file 272 of 364: salute - Jennifer - Extended.mp3
# Processing file 273 of 364: Samia - Minnesota - MICHELLE Remix.mp3
# Processing file 274 of 364: Sarah Kinsley - Cypress.mp3
# Processing file 275 of 364: Ship Wrek - It's My House (with Dillon Francis).mp3
# Processing file 276 of 364: Ship Wrek - Need It.mp3
# Processing file 277 of 364: Ship Wrek - Silent.mp3
# Processing file 278 of 364: Ship Wrek - The Function.mp3
# Processing file 279 of 364: Sigma - Nobody To Love.mp3
# Processing file 280 of 364: Skrillex, Fred again.., Flowdan - Rumble.mp3
# Processing file 281 of 364: Snakehips, MØ - Don't Leave - Throttle Remix.mp3
# Processing file 282 of 364: SQWAD - Big Ting Vibe.mp3
# Processing file 283 of 364: SQWAD - Dancerteria.mp3
# Processing file 284 of 364: SQWAD - Everybody.mp3
# Processing file 285 of 364: SQWAD, Badjokes, Habstrakt - Move.mp3
# Processing file 286 of 364: Starjunk 95 - Dozing Off Again... - House Edit.mp3
# Processing file 287 of 364: Starjunk 95 - Dreamfields.mp3
# Processing file 288 of 364: Starjunk 95 - Stardust Circuit.mp3
# Processing file 289 of 364: sumthin sumthin - Bloom.mp3
# Processing file 290 of 364: sumthin sumthin - Cut That.mp3
# Processing file 291 of 364: sumthin sumthin - Ghost.mp3
# Processing file 292 of 364: sumthin sumthin - Gryme.mp3
# Processing file 293 of 364: sumthin sumthin - Vivid.mp3
# Processing file 294 of 364: sumthin sumthin, CloZee - Salt.mp3
# Processing file 295 of 364: sumthin sumthin, Saka - Damage.mp3
# Processing file 296 of 364: Super Duper - Here with You.mp3
# Processing file 297 of 364: Taiki Nulight - Through Glass.mp3
# Processing file 298 of 364: Taiki Nulight, Dread MC - Soundwave.mp3
# Processing file 299 of 364: Taiki Nulight, LO'99 - Dr Sbaitso.mp3
# Processing file 300 of 364: Tame Impala - Patience - Maurice Fulton Remix.mp3
# Processing file 301 of 364: Tchami - Adieu (Chace Remix).mp3
# Processing file 302 of 364: Tchami - Don't Let Me Down (feat. Kaelyn Behr).mp3
# Processing file 303 of 364: Tchami - Godspell (feat. Taiki Nulight).mp3
# Processing file 304 of 364: Tchami - Omega (feat. Ibranovski).mp3
# Processing file 305 of 364: Tchami - Rainforest.mp3
# Processing file 306 of 364: Tchami - SIAW.mp3
# Processing file 307 of 364: Tchami - World To Me (feat. Luke James).mp3
# Processing file 308 of 364: Tchami - Zeal.mp3
# Processing file 309 of 364: Tchami, BROHUG - My Place (feat. Reece).mp3
# Processing file 310 of 364: Tchami, Malaa - Prophecy (Kyle Watson Remix).mp3
# Processing file 311 of 364: Tchami, Malaa - Prophecy.mp3
# Processing file 312 of 364: Teddi Gold - Pineapple Piñata - Party Pupils Remix.mp3
# Processing file 313 of 364: The Aces - Daydream - Snakehips Remix.mp3
# Processing file 314 of 364: The Deep - BAPPI.mp3
# Processing file 315 of 364: The Floozies, Gibbz, MZG - Denim.mp3
# Processing file 316 of 364: The Floozies, The Sponges - Hot Guy Alert.mp3
# Processing file 317 of 364: The Funk Hunters, Defunk, Akylla - Warn Ya - Cazztek Remix.mp3
# Processing file 318 of 364: The Knocks - Bang Bang (feat. Donna Missal).mp3
# Processing file 319 of 364: The Knocks - Bedroom Eyes (feat. Studio Killers).mp3
# Processing file 320 of 364: The Knocks - Dancing With The DJ.mp3
# Processing file 321 of 364: The Knocks - Gimme Love (feat. Yoke Lore).mp3
# Processing file 322 of 364: The Knocks - R U HIGH (feat. Mallrat).mp3
# Processing file 323 of 364: The Marías - Over the Moon.mp3
# Processing file 324 of 364: The Marías - Ruthless.mp3
# Processing file 325 of 364: The Sponges - Jerry Brain.mp3
# Processing file 326 of 364: Throttle - All In.mp3
# Processing file 327 of 364: Throttle - For Me - VIP.mp3
# Processing file 328 of 364: Tiësto, 7 Skies - My Frequency (feat. RebMoe).mp3
# Processing file 329 of 364: Tom Budin, Dave Winnel - Supersonic.mp3
# Processing file 330 of 364: TRANCEMAN2000 - Falling van Buuren.mp3
# Processing file 331 of 364: TroyBoi - Back To The Wall.mp3
# Processing file 332 of 364: TroyBoi - Grimey.mp3
# Processing file 333 of 364: TroyBoi - Sensei.mp3
# Processing file 334 of 364: TroyBoi, Destructo - You're the One For Me.mp3
# Processing file 335 of 364: TVBOO, um.. - Bleacher Creature.mp3
# Processing file 336 of 364: um.. - Don't Copy Us.mp3
# Processing file 337 of 364: Vince Staples - ROSE STREET.mp3
# Processing file 338 of 364: VINNE - Pó De Anjo.mp3
# Processing file 339 of 364: Virtual Self - Ghost Voices.mp3
# Processing file 340 of 364: Virtual Self - Key.mp3
# Processing file 341 of 364: VOLAC - Bump.mp3
# Processing file 342 of 364: VOLAC - Russian Style.mp3
# Processing file 343 of 364: VOLAC, Gustavo Mota - Like Dis - Radio Edit.mp3
# Processing file 344 of 364: Wafia - Good Things - R3HAB Remix.mp3
# Processing file 345 of 364: Wax Motif - Keep Raving.mp3
# Processing file 346 of 364: Wax Motif, Matroda - Lose Control.mp3
# Processing file 347 of 364: What So Not, Daniel Johns - Be Ok Again.mp3
# Processing file 348 of 364: What So Not, SLUMBERJACK - Warlord.mp3
# Processing file 349 of 364: WILLOW - Wait a Minute!.mp3
# Processing file 350 of 364: Wolfgang Gartner - 28 Grams.mp3
# Processing file 351 of 364: Wolfgang Gartner - Mike Tyson.mp3
# Processing file 352 of 364: Wolsh - Never Hide - Original Mix.mp3
# Processing file 353 of 364: XG - GRL GVNG.mp3
# Processing file 354 of 364: XG - LEFT RIGHT.mp3
# Processing file 355 of 364: XG - NEW DANCE.mp3
# Processing file 356 of 364: XG - SHOOTING STAR.mp3
# Processing file 357 of 364: Yaeji, OHHYUK - 29.mp3
# Processing file 358 of 364: YOASOBI - ミスター.mp3
# Processing file 359 of 364: Young & Sick - Queen of the Valley.mp3
# Processing file 360 of 364: Zedd - Done With Love.mp3
# Processing file 361 of 364: Zedd - Straight Into The Fire.mp3
# Processing file 362 of 364: Zedd, Aloe Blacc - Candyman.mp3
# Processing file 363 of 364: Zedd, Foxes - Clarity.mp3
# Processing file 364 of 364: Zonderling - Tunnel Vision - Don Diablo Edit.mp3

# %%
tracks_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.784   0.521    1    -5.701     1       0.0322       0.06200
# 1           0.905   0.838    6    -6.838     1       0.0499       0.00112
# 2           0.897   0.692   11    -4.985     0       0.0492       0.01870
# 3           0.724   0.792    1    -3.332     0       0.1020       0.01140
# 4           0.710   0.729    2    -4.978     1       0.0539       0.07430
# ..            ...     ...  ...       ...   ...          ...           ...
# 348         0.579   0.759    2    -5.584     0       0.0386       0.06000
# 349         0.583   0.860    8    -4.347     1       0.0842       0.02310
# 350         0.572   0.864    2    -4.098     0       0.0477       0.02150
# 351         0.509   0.781    8    -3.480     1       0.0720       0.03980
# 352         0.762   0.913    5    -4.101     0       0.1110       0.23300
#
#      instrumentalness  liveness  valence    tempo  time_signature  \
# 0            0.000005    0.0995    0.817  101.491               4
# 1            0.839000    0.6080    0.464  126.007               4
# 2            0.725000    0.0603    0.607  125.023               4
# 3            0.000008    0.6250    0.559  109.997               4
# 4            0.000004    0.0419    0.532  124.995               4
# ..                ...       ...      ...      ...             ...
# 348          0.000138    0.1170    0.127  127.875               4
# 349          0.000001    0.0977    0.279  127.032               4
# 350          0.000000    0.3750    0.260  149.945               4
# 351          0.000000    0.0749    0.176  128.000               4
# 352          0.470000    0.1100    0.365  126.001               4
#
#                    track_id  \
# 0    5q3LwAHTqo9d3rET2EA9Nq
# 1    0oUTyBEY3NQzmu2VuoKpSH
# 2    26xlCgHpcF4GE0FFVsS6Oy
# 3    2PAr2vrUwJs6QqRxDv0mP8
# 4    38TlYe1miTAL6r1FyJj7PS
# ..                      ...
# 348  0qlAureWHln3vDCsqnkyRE
# 349  1Aw0wPIW70GsV9KoD8m7Ps
# 350  0NWQTyapmz4GuDTSN9xTB7
# 351  60wwxj6Dd9NJlirf84wr2c
# 352  7s2fTKrE24gtReCNgnrRBo
#
#                                             artist_ids  \
# 0     [1AhjOkOLkbHUfcHDSErXQs, 6UbmqUEgjLA6jAcXwbM1Z9]
# 1                             [6EqFMCnVGBRNmwPlk2f3Uc]
# 2    [6EqFMCnVGBRNmwPlk2f3Uc, 7tm9Tuc70geXOOyKhtZHI...
# 3     [1NfT4THLhxNASM4xVImfNg, 4pnrk5QCXeKifcD98STB24]
# 4    [4AVFqumd2ogHFlRbKIjp1t, 0awl5piYwO0CDTHEkCjUh...
# ..                                                 ...
# 348                           [2qxJFvFYMEDqd7ui6kSAcq]
# 349                           [2qxJFvFYMEDqd7ui6kSAcq]
# 350   [2qxJFvFYMEDqd7ui6kSAcq, 0id62QV2SZZfvBn9xpmuCl]
# 351   [2qxJFvFYMEDqd7ui6kSAcq, 7qRll6DYV06u2VuRPAVqug]
# 352   [0bMKf3lIYR9GaNTdFKkTOr, 1l2ekx5skC4gJH8djERwh1]
#
#                                             genre_list  \
# 0          [k-pop, korean r&b, asian american hip hop]
# 1    [fidget house, brostep, electro house, bass ho...
# 2    [fidget house, house, tech house, bass house, ...
# 3        [kawaii future bass, kawaii edm, future bass]
# 4    [progressive electro house, pop, dutch house, ...
# ..                                                 ...
# 348   [pop, edm, complextro, german techno, pop dance]
# 349   [pop, edm, complextro, german techno, pop dance]
# 350  [pop soul, pop, r&b, edm, complextro, german t...
# 351  [uk pop, pop, metropopolis, edm, complextro, g...
# 352  [progressive electro house, future house, dutc...
#
#                                    track_name  \
# 0                                 The Weekend
# 1                                 Bass Inside
# 2                 Fly Kicks - Wax Motif Remix
# 3                                  Space Girl
# 4    I Wanna Know - Alesso & Deniz Koyu Remix
# ..                                        ...
# 348                            Done With Love
# 349                    Straight Into The Fire
# 350                                  Candyman
# 351                                   Clarity
# 352           Tunnel Vision - Don Diablo Edit
#
#                             artist_names  \
# 0                         88rising, BIBI
# 1                              AC Slater
# 2    AC Slater, Chris Lorenzo, Wax Motif
# 3                            AIKA, TOFIE
# 4        Alesso, Nico & Vinz, Deniz Koyu
# ..                                   ...
# 348                                 Zedd
# 349                                 Zedd
# 350                     Zedd, Aloe Blacc
# 351                          Zedd, Foxes
# 352               Zonderling, Don Diablo
#
#                                               filename
# 0                     88rising, BIBI - The Weekend.mp3
# 1                          AC Slater - Bass Inside.mp3
# 2    AC Slater, Chris Lorenzo - Fly Kicks - Wax Mot...
# 3                         AIKA, TOFIE - Space Girl.mp3
# 4    Alesso, Nico & Vinz - I Wanna Know - Alesso & ...
# ..                                                 ...
# 348                          Zedd - Done With Love.mp3
# 349                  Zedd - Straight Into The Fire.mp3
# 350                    Zedd, Aloe Blacc - Candyman.mp3
# 351                          Zedd, Foxes - Clarity.mp3
# 352   Zonderling - Tunnel Vision - Don Diablo Edit.mp3
#
# [353 rows x 18 columns]

# %%
tracks_df.to_csv(r'../data/dataframes/spotify_metadata.csv', index=False)

# %%
tracks_df
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.784   0.521    1    -5.701     1       0.0322       0.06200
# 1           0.905   0.838    6    -6.838     1       0.0499       0.00112
# 2           0.897   0.692   11    -4.985     0       0.0492       0.01870
# 3           0.724   0.792    1    -3.332     0       0.1020       0.01140
# 4           0.710   0.729    2    -4.978     1       0.0539       0.07430
# ..            ...     ...  ...       ...   ...          ...           ...
# 348         0.579   0.759    2    -5.584     0       0.0386       0.06000
# 349         0.583   0.860    8    -4.347     1       0.0842       0.02310
# 350         0.572   0.864    2    -4.098     0       0.0477       0.02150
# 351         0.509   0.781    8    -3.480     1       0.0720       0.03980
# 352         0.762   0.913    5    -4.101     0       0.1110       0.23300
#
#      instrumentalness  liveness  valence    tempo  time_signature  \
# 0            0.000005    0.0995    0.817  101.491               4
# 1            0.839000    0.6080    0.464  126.007               4
# 2            0.725000    0.0603    0.607  125.023               4
# 3            0.000008    0.6250    0.559  109.997               4
# 4            0.000004    0.0419    0.532  124.995               4
# ..                ...       ...      ...      ...             ...
# 348          0.000138    0.1170    0.127  127.875               4
# 349          0.000001    0.0977    0.279  127.032               4
# 350          0.000000    0.3750    0.260  149.945               4
# 351          0.000000    0.0749    0.176  128.000               4
# 352          0.470000    0.1100    0.365  126.001               4
#
#                    track_id  \
# 0    5q3LwAHTqo9d3rET2EA9Nq
# 1    0oUTyBEY3NQzmu2VuoKpSH
# 2    26xlCgHpcF4GE0FFVsS6Oy
# 3    2PAr2vrUwJs6QqRxDv0mP8
# 4    38TlYe1miTAL6r1FyJj7PS
# ..                      ...
# 348  0qlAureWHln3vDCsqnkyRE
# 349  1Aw0wPIW70GsV9KoD8m7Ps
# 350  0NWQTyapmz4GuDTSN9xTB7
# 351  60wwxj6Dd9NJlirf84wr2c
# 352  7s2fTKrE24gtReCNgnrRBo
#
#                                             artist_ids  \
# 0     [1AhjOkOLkbHUfcHDSErXQs, 6UbmqUEgjLA6jAcXwbM1Z9]
# 1                             [6EqFMCnVGBRNmwPlk2f3Uc]
# 2    [6EqFMCnVGBRNmwPlk2f3Uc, 7tm9Tuc70geXOOyKhtZHI...
# 3     [1NfT4THLhxNASM4xVImfNg, 4pnrk5QCXeKifcD98STB24]
# 4    [4AVFqumd2ogHFlRbKIjp1t, 0awl5piYwO0CDTHEkCjUh...
# ..                                                 ...
# 348                           [2qxJFvFYMEDqd7ui6kSAcq]
# 349                           [2qxJFvFYMEDqd7ui6kSAcq]
# 350   [2qxJFvFYMEDqd7ui6kSAcq, 0id62QV2SZZfvBn9xpmuCl]
# 351   [2qxJFvFYMEDqd7ui6kSAcq, 7qRll6DYV06u2VuRPAVqug]
# 352   [0bMKf3lIYR9GaNTdFKkTOr, 1l2ekx5skC4gJH8djERwh1]
#
#                                             genre_list  \
# 0          [k-pop, korean r&b, asian american hip hop]
# 1    [fidget house, brostep, electro house, bass ho...
# 2    [fidget house, house, tech house, bass house, ...
# 3        [kawaii future bass, kawaii edm, future bass]
# 4    [progressive electro house, pop, dutch house, ...
# ..                                                 ...
# 348   [pop, edm, complextro, german techno, pop dance]
# 349   [pop, edm, complextro, german techno, pop dance]
# 350  [pop soul, pop, r&b, edm, complextro, german t...
# 351  [uk pop, pop, metropopolis, edm, complextro, g...
# 352  [progressive electro house, future house, dutc...
#
#                                    track_name  \
# 0                                 The Weekend
# 1                                 Bass Inside
# 2                 Fly Kicks - Wax Motif Remix
# 3                                  Space Girl
# 4    I Wanna Know - Alesso & Deniz Koyu Remix
# ..                                        ...
# 348                            Done With Love
# 349                    Straight Into The Fire
# 350                                  Candyman
# 351                                   Clarity
# 352           Tunnel Vision - Don Diablo Edit
#
#                             artist_names  \
# 0                         88rising, BIBI
# 1                              AC Slater
# 2    AC Slater, Chris Lorenzo, Wax Motif
# 3                            AIKA, TOFIE
# 4        Alesso, Nico & Vinz, Deniz Koyu
# ..                                   ...
# 348                                 Zedd
# 349                                 Zedd
# 350                     Zedd, Aloe Blacc
# 351                          Zedd, Foxes
# 352               Zonderling, Don Diablo
#
#                                               filename
# 0                     88rising, BIBI - The Weekend.mp3
# 1                          AC Slater - Bass Inside.mp3
# 2    AC Slater, Chris Lorenzo - Fly Kicks - Wax Mot...
# 3                         AIKA, TOFIE - Space Girl.mp3
# 4    Alesso, Nico & Vinz - I Wanna Know - Alesso & ...
# ..                                                 ...
# 348                          Zedd - Done With Love.mp3
# 349                  Zedd - Straight Into The Fire.mp3
# 350                    Zedd, Aloe Blacc - Candyman.mp3
# 351                          Zedd, Foxes - Clarity.mp3
# 352   Zonderling - Tunnel Vision - Don Diablo Edit.mp3
#
# [353 rows x 18 columns]
